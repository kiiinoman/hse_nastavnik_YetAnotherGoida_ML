# %%
# !pip install boto3 pandas==2.0.3 psycopg2-binary sqlalchemy pyarrow==12.0.1 numpy==1.24.3
# Out:
# ...
#   Using cached boto3-1.43.10-py3-none-any.whl.metadata (6.6 kB)
# ...
#   Using cached psycopg2_binary-2.9.12-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (4.9 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 12.3 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.9/38.9 MB 9.6 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 9.5 MB/s eta 0:00:0000:0100:01
# Using cached boto3-1.43.10-py3-none-any.whl (140 kB)
# Using cached psycopg2_binary-2.9.12-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.3 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 10.1 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 349.3/349.3 kB 9.6 MB/s eta 0:00:00:00:01
# ...

# %%
import pandas as pd
import pyarrow
import boto3
import psycopg2
import sqlalchemy

print("Все пакеты установлены!")
# Out:
# Все пакеты установлены!

# %%
import psycopg2

conn = psycopg2.connect(
    host='postgres_db',
    port=5432,
    user='admin',
    password='admin',
    database='oil_db'
)
cursor = conn.cursor()
cursor.execute("SELECT COUNT(*) FROM wells;")
print(f"Скважин: {cursor.fetchone()[0]}")
conn.close()
# Out:
# Скважин: 5

# %%
import boto3

s3 = boto3.client(
    's3',
    endpoint_url='http://minio:9000',
    aws_access_key_id='admin',
    aws_secret_access_key='admin123',
    verify=False
)

# %%
s3.create_bucket(Bucket='oil-data')
print("Бакет создан")
# Out:
# Бакет создан
